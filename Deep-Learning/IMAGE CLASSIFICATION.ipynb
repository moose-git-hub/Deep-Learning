# %%
pip install torchvision
# Out:
# Collecting torchvision
#   Downloading torchvision-0.11.3-cp39-cp39-win_amd64.whl (947 kB)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in c:\users\morri\anaconda3\lib\site-packages (from torchvision) (8.4.0)
# Requirement already satisfied: torch==1.10.2 in c:\users\morri\anaconda3\lib\site-packages (from torchvision) (1.10.2)
# Requirement already satisfied: numpy in c:\users\morri\anaconda3\lib\site-packages (from torchvision) (1.20.3)
# Requirement already satisfied: typing-extensions in c:\users\morri\anaconda3\lib\site-packages (from torch==1.10.2->torchvision) (3.10.0.2)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.11.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
print(torch.__version__)

# %%
print(torch.cuda.is_available())
# Out:
# False

# %%
import urllib.request

# %%
url="https://github.com/Joseph-Morris/Deep-Learning/blob/main/German-Shepherd-on-White-00.jpg?raw=true"

# %%
file_name = "dog.jpg"

# %%
urllib.request.urlretrieve(url, file_name)
# Out:
# ('dog.jpg', <http.client.HTTPMessage at 0x1da3bbed5e0>)

# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = Image.open("dog.jpg")
plt.imshow(img)

# %%
from torchvision import transforms

# %%
preprocess = transforms.Compose([
                                 transforms.Resize(256),
                                 transforms.CenterCrop(224),
                                 transforms.ToTensor(),
                                 transforms.Normalize(
                                     mean = [0.485, 0.456, 0.406],
                                     std = [0.229, 0.224, 0.225]
                                 )
])

# %%
img_tensor = preprocess(img)

# %%
img_tensor.shape
# Out:
# torch.Size([3, 224, 224])

# %%
batch = img_tensor.unsqueeze(0)

# %%
batch.shape
# Out:
# torch.Size([1, 3, 224, 224])

# %%
from torchvision import models

# %%
model = models.alexnet(pretrained = True)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to C:\Users\morri/.cache\torch\hub\checkpoints\alexnet-owt-7be5be79.pth
#   0%|          | 0.00/233M [00:00<?, ?B/s]

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
model.eval()
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
model.to(device)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
y = model(batch.to(device))

# %%
y.shape
# Out:
# torch.Size([1, 1000])

# %%
y_max, index = torch.max(y,1)
print(index, y_max)
# Out:
# tensor([225]) tensor([25.9716], grad_fn=<MaxBackward0>)

# %%
url = "http://pytorch.tips/imagenet-labels"

# %%
fname = "imagenet_class_labels.txt"

# %%
urllib.request.urlretrieve(url, fname)
# Out:
# ('imagenet_class_labels.txt', <http.client.HTTPMessage at 0x1da43a6df10>)

# %%
with open("imagenet_class_labels.txt") as f:
  classes = [line.strip() for line in f.readlines()]

# %%
print(classes[258])
# Out:
# 258: 'Samoyed, Samoyede',

# %%
prob = torch.nn.functional.softmax(y, dim=1)[0]*100

# %%
print(classes[index[0]],
      prob[index[0]].item())
# Out:
# 225: 'malinois', 59.637088775634766

# %%
_, indeces = torch.sort(y, descending=True)

# %%
for idx in indeces[0][:5]:
  print(classes[idx], prob[idx].item())
# Out:
# 225: 'malinois', 59.637088775634766
# 235: 'German shepherd, German shepherd dog, German police dog, alsatian', 40.07558059692383
# 246: 'Great Dane', 0.16354498267173767
# 184: 'Irish terrier', 0.05604846030473709
# 182: 'Border terrier', 0.020665613934397697
